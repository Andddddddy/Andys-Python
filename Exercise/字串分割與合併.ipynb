# %% [markdown]
# # 字串分割與合併
# ![image.png](attachment:image.png)

# %%
say = input()
say = say.split()

r_say = say[::-1]

print(" ".join(r_say))
#done
# Out:
# Python has a lot of interesting things you can do with strings
# strings with do can you things interesting of lot a has Python
