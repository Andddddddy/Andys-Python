# %% [markdown]
# # 有幾隻腳?
# ![image.png](attachment:image.png)

# %%
n = input().split()
print("{} total has {} legs.".format(n[0], int(n[1])*6 + int(n[2])*8))
#done
# Out:
# Johnson 2 7
# Johnson total has 68 legs.
