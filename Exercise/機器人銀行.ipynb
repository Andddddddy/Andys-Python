# %% [markdown]
# # 機器人銀行
# ![image.png](attachment:image.png)

# %%
money = input()
a, b, n = money.split()[0], money.split()[1], money.split()[2]

result = int(b) * ( (1+float(a)/100)**(int(n)*2) )
print(round(result))
#done
# Out:
# 1.2 1000 10
# 1269
