# %% [markdown]
# # 金字塔
# ![image.png](attachment:image.png)

# %%
n = int(input())
def pyramid(n):
    for i in range(1, n+1):
        print(" "*(n-i) + "* "*(i-1) + "*")

pyramid(n)
# Out:
# 10
#          *
#         * *
#        * * *
#       * * * *
#      * * * * *
#     * * * * * *
#    * * * * * * *
#   * * * * * * * *
#  * * * * * * * * *
# * * * * * * * * * *
