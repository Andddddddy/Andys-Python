# %% [markdown]
# # 刮刮樂兌獎
# ![image.png](attachment:image.png)

# %%
p = input()
pList = p.split()

p1 = pList[0]
p2 = pList[1]

reward = 0
if int(p1)%2 == 1:
    reward += 100

if p2 in "258":
    reward += 200

if p1 == p2:
    reward += 50
    
print(reward)
#done
# Out:
# 1 3
# 100
