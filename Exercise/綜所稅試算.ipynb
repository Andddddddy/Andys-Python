# %% [markdown]
# # 綜所稅試算
# ![image.png](attachment:image.png)

# %%
income_tax = int(input())

if income_tax >= 0 and income_tax <= 540000:
    print(round(income_tax * 0.05))

if income_tax >= 540001 and income_tax <= 1210000:
    print(round(income_tax * 0.12))

if income_tax >= 1210001 and income_tax <= 2420000:
    print(round(income_tax * 0.2))
    
if income_tax >= 2420001 and income_tax <= 4530000:
    print(round(income_tax * 0.3))
    
if income_tax >= 4530001 and income_tax <= 10310000:
    print(round(income_tax * 0.4))
    
if income_tax >= 10310001:
    print(round(income_tax * 0.45))
#done
# Out:
# 600000
# 72000
