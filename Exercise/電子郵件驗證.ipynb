# %% [markdown]
# # 電子郵件驗證
# ![image.png](attachment:image.png)

# %%
def email_checker():
    n = int(input())
    for i in range(n):
        e = input()
        if len(e.split('@')) !=2:
            return 'Invalid'
        else:
            if len(e.split('@')[1].split(".")) !=2:
                return 'Invalid'
        
        a = e.find("@")
        dot = e.find(".")
            
        if e[:a] != "" and e[a+1:dot] != "":
            if e[:a].islower() == True and e[a+1:dot].isalnum() == True and len(e[dot+1:]) <= 3:
                print("Valid")
            else:
                print("Invalid")

email_checker()

# %%
import re

def email_checker():
    n = int(input())
    for i in range(n):
        e = input()
        if "@" and "." in e and e.count("@", 0, len(e)) == 1 and e.count(".", 0, len(e)) == 1:
            a = e.find("@")
            dot = e.find(".")
            
            if e[:a] != "" and e[a+1:dot] != "":
                e_user = re.sub("[a-z0-9\-\_]", "", email[:a])
                e_web = re.sub("[a-z0-9]", "", email[a+1:dot])
                if len(e_user) == 0 and len(e_web) == 0 and (len(e[dot+1:]) <= 3 and len(e[dot+1:]) >= 1):
                    print("Valid")
                else:
                    print("Invalid")
            else:
                print("Invalid")
        else:
            print("Invalid")

email_checker()
