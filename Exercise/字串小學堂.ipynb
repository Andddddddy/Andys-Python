# %% [markdown]
# # 字串小學堂
# ![image.png](attachment:image.png)

# %%
s1 = input().split()
s2 = input().split()
s3 = input().split()

s1.sort()
s2.sort()
s3.sort()

result = []
result.append(s1)
result.append(s2)
result.append(s3)
result.sort()

print("{} {} {}.".format(result[0][1], result[1][1], result[2][1]))
#done
# Out:
# pretty 2
# good 3
# That's 1
# That's pretty good.
